# %%
# Add the Pandas dependency
import pandas as pd
import numpy as np

# %%
# Files to load
student_data_to_load = "Resources/students_complete.csv"

# Read the student data file and store it in a Pandas DataFrame.
student_data_df = pd.read_csv(student_data_to_load)
student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# 2                 90          60
# ...

# %%
student_data_df.loc[(student_data_df['school_name'] == "Thomas High School") 
                        & (student_data_df['grade'] == "9th"), 'reading_score'] = np.nan

student_data_df.loc[(student_data_df['school_name'] == "Thomas High School") 
                        & (student_data_df['grade'] == "9th"), 'math_score'] = np.nan

student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0               66.0        79.0
# 1               94.0        61.0
# 2               90.0        60.0
# ...

# %%
# Create DataFrame containing only Thomas High School Freshmen

thomas_student = student_data_df['school_name'] == "Thomas High School"

freshmen = student_data_df['grade'] == "9th"

thomas_freshmen_df = pd.DataFrame(student_data_df[thomas_student & freshmen])


thomas_freshmen_df
# Out:
#        Student ID      student_name gender grade         school_name  \
# 37537       37537       Erik Snyder      M   9th  Thomas High School
# 37538       37538    Tanya Martinez      F   9th  Thomas High School
# 37539       37539     Noah Erickson      M   9th  Thomas High School
# 37540       37540      Austin Meyer      M   9th  Thomas High School
# 37543       37543   Madison Hampton      F   9th  Thomas High School
# ...           ...               ...    ...   ...                 ...
# 39152       39152        Lori Moore      F   9th  Thomas High School
# 39153       39153   William Hubbard      M   9th  Thomas High School
# 39157       39157  Kristen Gonzalez      F   9th  Thomas High School
# 39164       39164    Joseph Anthony      M   9th  Thomas High School
# 39167       39167    Rebecca Tanner      F   9th  Thomas High School
#
#        reading_score  math_score
# 37537            NaN         NaN
# 37538            NaN         NaN
# 37539            NaN         NaN
# ...

# %%
# Replace currupted grades with NaN

thomas_freshmen_df.loc[:, ['reading_score', 'math_score']] = np.nan

thomas_freshmen_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-d86ad7cb8f87> in <module>
#       1 # Replace currupted grades with NaN
#       2
# ----> 3 thomas_freshmen_df.loc[:, ['reading_score', 'math_score']] = np.nan
#       4
#       5 thomas_freshmen_df.head()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668         else:
#     669             key = com.apply_if_callable(key, self.obj)
# --> 670         indexer = self._get_setitem_indexer(key)
#     671         self._setitem_with_indexer(indexer, value)
#     672
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     646         if isinstance(key, tuple):
#     647             try:
# --> 648                 return self._convert_tuple(key)
# ...
